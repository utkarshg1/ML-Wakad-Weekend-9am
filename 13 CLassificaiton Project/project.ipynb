# %% [markdown]
# # Machine failure project

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %%
import os 
import sys

# %%
print(os.getcwd())
# Out:
# c:\ML_Wakad_Weekend_9am\13 CLassificaiton Project

# %%
root_path = os.path.abspath(os.path.join(os.getcwd(), ".."))
print(root_path)
# Out:
# c:\ML_Wakad_Weekend_9am

# %%
if root_path not in sys.path:
    sys.path.append(root_path)

# %%
from utils import algo_evaluation

# %% [markdown]
# # Step 1 - Data ingestion

# %%
import pandas as pd
df = pd.read_csv("train_machine.csv")
df.head()
# Out:
#    id Product ID Type  Air temperature [K]  ...  HDF  PWF  OSF  RNF
# 0   0     L50096    L                300.6  ...    0    0    0    0
# 1   1     M20343    M                302.6  ...    0    0    0    0
# 2   2     L49454    L                299.3  ...    0    0    0    0
# 3   3     L53355    L                301.0  ...    0    0    0    0
# 4   4     M24050    M                298.0  ...    0    0    0    0
#
# [5 rows x 14 columns]

# %% [markdown]
# # Target feature - Machine failure

# %% [markdown]
# # Step 2 - Perform basic data quality checks

# %%
df.shape
# Out:
# (136429, 14)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# id                         0
# Product ID                 0
# Type                       0
# Air temperature [K]        0
# Process temperature [K]    0
# Rotational speed [rpm]     0
# Torque [Nm]                0
# Tool wear [min]            0
# Machine failure            0
# TWF                        0
# HDF                        0
# PWF                        0
# OSF                        0
# RNF                        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136429 entries, 0 to 136428
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       136429 non-null  int64
#  1   Product ID               136429 non-null  object
#  2   Type                     136429 non-null  object
#  3   Air temperature [K]      136429 non-null  float64
#  4   Process temperature [K]  136429 non-null  float64
#  5   Rotational speed [rpm]   136429 non-null  int64
#  6   Torque [Nm]              136429 non-null  float64
#  7   Tool wear [min]          136429 non-null  int64
#  8   Machine failure          136429 non-null  int64
#  9   TWF                      136429 non-null  int64
#  10  HDF                      136429 non-null  int64
#  11  PWF                      136429 non-null  int64
#  12  OSF                      136429 non-null  int64
# ...

# %%
df.select_dtypes(include = "object").nunique()
# Out:
# Product ID    9976
# Type             3
# dtype: int64

# %% [markdown]
# # Product ID should be dropped because of too many uniqye values

# %% [markdown]
# # Step 3 - Seperate X and Y (Machine failure)

# %%
X = df.drop(columns=["id", "Product ID", "Machine failure"])
Y = df["Machine failure"]

# %%
X.head()
# Out:
#   Type  Air temperature [K]  Process temperature [K]  ...  PWF  OSF  RNF
# 0    L                300.6                    309.6  ...    0    0    0
# 1    M                302.6                    312.1  ...    0    0    0
# 2    L                299.3                    308.5  ...    0    0    0
# 3    L                301.0                    310.9  ...    0    0    0
# 4    M                298.0                    309.0  ...    0    0    0
#
# [5 rows x 11 columns]

# %%
Y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Machine failure, dtype: int64

# %%
Y.value_counts()
# Out:
# Machine failure
# 0    134281
# 1      2148
# Name: count, dtype: int64

# %%
Y.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Machine failure'>

# %% [markdown]
# # Step 4 - apply train test split

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
xtrain.head()
# Out:
#        Type  Air temperature [K]  Process temperature [K]  ...  PWF  OSF  RNF
# 12407     L                301.5                    310.7  ...    0    0    0
# 85011     L                300.7                    309.5  ...    0    0    0
# 65292     M                298.5                    309.1  ...    0    0    0
# 18478     L                301.6                    310.7  ...    0    0    0
# 100267    L                298.9                    308.6  ...    0    0    0
#
# [5 rows x 11 columns]

# %%
ytrain.head()
# Out:
# 12407     0
# 85011     0
# 65292     0
# 18478     0
# 100267    0
# Name: Machine failure, dtype: int64

# %%
xtest.head()
# Out:
#        Type  Air temperature [K]  Process temperature [K]  ...  PWF  OSF  RNF
# 123128    L                300.9                    310.7  ...    0    1    0
# 54705     L                300.5                    311.3  ...    0    0    0
# 40016     L                300.6                    310.4  ...    0    0    0
# 75025     L                297.6                    308.4  ...    0    0    0
# 120421    L                300.8                    310.7  ...    0    0    0
#
# [5 rows x 11 columns]

# %%
ytest.head()
# Out:
# 123128    1
# 54705     0
# 40016     0
# 75025     0
# 120421    0
# Name: Machine failure, dtype: int64

# %% [markdown]
# # Step 5 - Apply preprocessing

# %%
cat_cols = X.select_dtypes(include="object").columns.tolist()
cat_cols
# Out:
# ['Type']

# %%
num_cols = X.select_dtypes(include="number").columns.tolist()
num_cols
# Out:
# ['Air temperature [K]',
#  'Process temperature [K]',
#  'Rotational speed [rpm]',
#  'Torque [Nm]',
#  'Tool wear [min]',
#  'TWF',
#  'HDF',
#  'PWF',
#  'OSF',
#  'RNF']

# %%
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
num_pipe = make_pipeline(
    SimpleImputer(strategy="median"),
    StandardScaler()
)

# %%
cat_pipe = make_pipeline(
    SimpleImputer(strategy="most_frequent"),
    OneHotEncoder(handle_unknown="ignore", sparse_output=False, drop="first")
)

# %%
pre = ColumnTransformer(
    [
        ("num", num_pipe, num_cols),
        ("cat", cat_pipe, cat_cols)
    ]
).set_output(transform="pandas")

# %%
pre.fit(xtrain)
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['Air temperature [K]',
#                                   'Process temperature [K]',
#                                   'Rotational speed [rpm]', 'Torque [Nm]',
#                                   'Tool wear [min]', 'TWF', 'HDF', 'PWF', 'OSF',
#                                   'RNF']),
#                                 ('cat',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
# ...

# %%
xtrain_pre = pre.transform(xtrain)
xtrain_pre.head()
# Out:
#         num__Air temperature [K]  ...  cat__Type_M
# 12407                   0.879407  ...          0.0
# 85011                   0.449463  ...          0.0
# 65292                  -0.732883  ...          1.0
# 18478                   0.933150  ...          0.0
# 100267                 -0.517911  ...          0.0
#
# [5 rows x 12 columns]

# %%
xtest_pre = pre.transform(xtest)
xtrain_pre.head()
# Out:
#         num__Air temperature [K]  ...  cat__Type_M
# 12407                   0.879407  ...          0.0
# 85011                   0.449463  ...          0.0
# 65292                  -0.732883  ...          1.0
# 18478                   0.933150  ...          0.0
# 100267                 -0.517911  ...          0.0
#
# [5 rows x 12 columns]

# %% [markdown]
# # Step 6 - Algo evaluation

# %%
# !uv add xgboost
# Out:
# Resolved 123 packages in 15ms
# Audited 118 packages in 0.52ms

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, HistGradientBoostingClassifier
from xgboost import XGBClassifier

# %%
RANDOM_STATE = 42

models = [
    LogisticRegression(random_state=RANDOM_STATE),
    DecisionTreeClassifier(random_state=RANDOM_STATE),
    RandomForestClassifier(random_state=RANDOM_STATE,max_depth=3),
    HistGradientBoostingClassifier(random_state=RANDOM_STATE,max_depth=3),
    XGBClassifier(random_state=RANDOM_STATE,max_depth=3)
]

# %%
xtrain.values, ytrain.values
# Out:
# (array([['L', 301.5, 310.7, ..., 0, 0, 0],
#         ['L', 300.7, 309.5, ..., 0, 0, 0],
#         ['M', 298.5, 309.1, ..., 0, 0, 0],
#         ...,
#         ['M', 301.1, 310.7, ..., 0, 0, 0],
#         ['H', 300.8, 311.4, ..., 0, 0, 0],
#         ['H', 300.2, 309.8, ..., 0, 0, 0]],
#        shape=(109143, 11), dtype=object),
#  array([0, 0, 0, ..., 0, 0, 0], shape=(109143,)))

# %%
best_model, eval_df = algo_evaluation(
    models, xtrain_pre.values, ytrain.values, xtest_pre.values, ytest.values
)
# Out:
# {'model_name': 'LogisticRegression', 'model': LogisticRegression(random_state=42), 'cv_mean': np.float64(0.9301), 'cv_std': np.float64(0.0092), 'f1_train': 0.9303, 'f1_test': 0.9315, 'gen_err': 0.0012}
# {'model_name': 'DecisionTreeClassifier', 'model': DecisionTreeClassifier(random_state=42), 'cv_mean': np.float64(0.8693), 'cv_std': np.float64(0.0085), 'f1_train': 0.9975, 'f1_test': 0.8808, 'gen_err': 0.1167}
# {'model_name': 'RandomForestClassifier', 'model': RandomForestClassifier(max_depth=3, random_state=42), 'cv_mean': np.float64(0.8896), 'cv_std': np.float64(0.0059), 'f1_train': 0.8843, 'f1_test': 0.8778, 'gen_err': 0.0065}
# {'model_name': 'HistGradientBoostingClassifier', 'model': HistGradientBoostingClassifier(max_depth=3, random_state=42), 'cv_mean': np.float64(0.9299), 'cv_std': np.float64(0.0089), 'f1_train': 0.9303, 'f1_test': 0.9315, 'gen_err': 0.0012}
# {'model_name': 'XGBClassifier', 'model': XGBClassifier(base_score=None, booster=None, callbacks=None,
# ...

# %%
eval_df
# Out:
#                        model_name  ... gen_err
# 0              LogisticRegression  ...  0.0012
# 1  HistGradientBoostingClassifier  ...  0.0012
# 2                   XGBClassifier  ...  0.0031
# 3          RandomForestClassifier  ...  0.0065
# 4          DecisionTreeClassifier  ...  0.1167
#
# [5 rows x 7 columns]

# %%
eval_df.to_csv("eval.csv", index=False)

# %%
best_model
# Out:
# LogisticRegression(random_state=42)

# %% [markdown]
# # Step 7 - Evaluated selected model in detail

# %%
best_model.score(xtrain_pre, ytrain)
# Out:
# 0.9961884866642845

# %%
best_model.score(xtest_pre, ytest)
# Out:
# 0.9961518727552591

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_estimator(
    best_model, xtest_pre, ytest
)

# %%
from sklearn.metrics import classification_report

ypred_test = best_model.predict(xtest_pre)
print(classification_report(ytest, ypred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     26848
#            1       0.99      0.77      0.86       438
#
#     accuracy                           1.00     27286
#    macro avg       0.99      0.88      0.93     27286
# weighted avg       1.00      1.00      1.00     27286

# %%
from sklearn.metrics import RocCurveDisplay

RocCurveDisplay.from_estimator(best_model, xtest_pre, ytest)

# %% [markdown]
# # Step 8 - Out of sample prediction

# %%
xnew = pd.read_csv("test_machine.csv")
xnew.head()
# Out:
#        id Product ID Type  Air temperature [K]  ...  HDF  PWF  OSF  RNF
# 0  136429     L50896    L                302.3  ...    0    0    0    0
# 1  136430     L53866    L                301.7  ...    0    0    0    0
# 2  136431     L50498    L                301.3  ...    0    0    0    0
# 3  136432     M21232    M                300.1  ...    0    0    0    0
# 4  136433     M19751    M                303.4  ...    0    0    0    0
#
# [5 rows x 13 columns]

# %%
best_model
# Out:
# LogisticRegression(random_state=42)

# %%
pre
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['Air temperature [K]',
#                                   'Process temperature [K]',
#                                   'Rotational speed [rpm]', 'Torque [Nm]',
#                                   'Tool wear [min]', 'TWF', 'HDF', 'PWF', 'OSF',
#                                   'RNF']),
#                                 ('cat',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
# ...

# %%
xnew_pre = pre.transform(xnew)
xnew_pre.head()
# Out:
#    num__Air temperature [K]  ...  cat__Type_M
# 0                  1.309351  ...          0.0
# 1                  0.986893  ...          0.0
# 2                  0.771921  ...          0.0
# 3                  0.127005  ...          1.0
# 4                  1.900524  ...          1.0
#
# [5 rows x 12 columns]

# %%
preds = best_model.predict(xnew_pre)
preds
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(90954,))

# %%
probs = best_model.predict_proba(xnew_pre)[:, 1]
probs
# Out:
# array([0.00209708, 0.00104179, 0.00271243, ..., 0.00312019, 0.00252358,
#        0.00214178], shape=(90954,))

# %%
best_model.classes_
# Out:
# array([0, 1])

# %%
res = xnew[["id"]]
res["machine_failure"] = preds
res["probability"] = probs.round(4)

# %%
res
# Out:
#            id  machine_failure  probability
# 0      136429                0       0.0021
# 1      136430                0       0.0010
# 2      136431                0       0.0027
# 3      136432                0       0.0032
# 4      136433                0       0.0038
# ...       ...              ...          ...
# 90949  227378                0       0.0022
# 90950  227379                0       0.0004
# 90951  227380                0       0.0031
# 90952  227381                0       0.0025
# 90953  227382                0       0.0021
#
# [90954 rows x 3 columns]

# %%
res[res["machine_failure"] == 1]
# Out:
#            id  machine_failure  probability
# 17     136446                1       0.9925
# 209    136638                1       0.9966
# 223    136652                1       0.9902
# 397    136826                1       0.9976
# 405    136834                1       0.9991
# ...       ...              ...          ...
# 90503  226932                1       0.9915
# 90665  227094                1       0.9999
# 90679  227108                1       0.7744
# 90784  227213                1       0.9827
# 90817  227246                1       0.9967
#
# [1106 rows x 3 columns]

# %%
res["machine_failure"].value_counts()
# Out:
# machine_failure
# 0    89848
# 1     1106
# Name: count, dtype: int64

# %%
res["machine_failure"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='machine_failure'>

# %% [markdown]
# # Step 9 - Save the model object and pre

# %%
pre
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['Air temperature [K]',
#                                   'Process temperature [K]',
#                                   'Rotational speed [rpm]', 'Torque [Nm]',
#                                   'Tool wear [min]', 'TWF', 'HDF', 'PWF', 'OSF',
#                                   'RNF']),
#                                 ('cat',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
# ...

# %%
best_model
# Out:
# LogisticRegression(random_state=42)

# %%
import joblib

joblib.dump(best_model, "machine_model.joblib")
# Out:
# ['machine_model.joblib']

# %%
joblib.dump(pre, "pre.joblib")
# Out:
# ['pre.joblib']

# %%
p = joblib.load("pre.joblib")
p
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['Air temperature [K]',
#                                   'Process temperature [K]',
#                                   'Rotational speed [rpm]', 'Torque [Nm]',
#                                   'Tool wear [min]', 'TWF', 'HDF', 'PWF', 'OSF',
#                                   'RNF']),
#                                 ('cat',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
# ...

# %%
m = joblib.load("machine_model.joblib")
m
# Out:
# LogisticRegression(random_state=42)
