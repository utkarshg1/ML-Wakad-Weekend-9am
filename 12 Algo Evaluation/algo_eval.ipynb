# %% [markdown]
# # Algorithm Evaluation
# Pick the best model for a given dataset

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# # Add the root directory in path

# %%
import os 
import sys

# %%
os.getcwd()
# Out:
# 'c:\\ML_Wakad_Weekend_9am\\12 Algo Evaluation'

# %%
parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
parent_dir
# Out:
# 'c:\\ML_Wakad_Weekend_9am'

# %%
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

# %%
# Import functions from utils.py file
from utils import evaluate_single_model_class, algo_evaluation

# %% [markdown]
# # Step 1 - Data ingestion

# %%
import pandas as pd

df = pd.read_csv("train_loan.csv")
df.head()
# Out:
#    id  person_age  ...  cb_person_cred_hist_length loan_status
# 0   0          37  ...                          14           0
# 1   1          22  ...                           2           0
# 2   2          29  ...                          10           0
# 3   3          30  ...                           5           0
# 4   4          22  ...                           3           0
#
# [5 rows x 13 columns]

# %% [markdown]
# # Loan Status is Target Feature
# 1. 0 - Loan is rejected
# 2. 1 - Loan is approved

# %% [markdown]
# # Step 2 - Perform basic data quality checks

# %%
df.shape
# Out:
# (58645, 13)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# id                            0
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_int_rate                 0
# loan_percent_income           0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# loan_status                   0
# dtype: int64

# %%
df.select_dtypes(include="object").nunique()
# Out:
# person_home_ownership        4
# loan_intent                  6
# loan_grade                   7
# cb_person_default_on_file    2
# dtype: int64

# %% [markdown]
# # Step 3 - Seperate X and Y(loan_status)

# %%
X = df.drop(columns=["id", "loan_status"])
Y = df["loan_status"]

# %%
X.head()
# Out:
#    person_age  ...  cb_person_cred_hist_length
# 0          37  ...                          14
# 1          22  ...                           2
# 2          29  ...                          10
# 3          30  ...                           5
# 4          22  ...                           3
#
# [5 rows x 11 columns]

# %%
Y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: loan_status, dtype: int64

# %%
Y.value_counts()
# Out:
# loan_status
# 0    50295
# 1     8350
# Name: count, dtype: int64

# %%
Y.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='loan_status'>

# %% [markdown]
# # Step 4 - Train test split

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(
    X, Y, test_size=0.2, random_state=42
)

# %%
xtrain.head()
# Out:
#        person_age  ...  cb_person_cred_hist_length
# 14337          36  ...                          15
# 17117          27  ...                           9
# 32590          25  ...                           3
# 55811          39  ...                          11
# 40120          22  ...                           2
#
# [5 rows x 11 columns]

# %%
ytrain.head()
# Out:
# 14337    0
# 17117    0
# 32590    0
# 55811    0
# 40120    0
# Name: loan_status, dtype: int64

# %%
xtest.head()
# Out:
#        person_age  ...  cb_person_cred_hist_length
# 4657           23  ...                           4
# 56440          25  ...                           4
# 42117          32  ...                           6
# 10849          22  ...                           2
# 39395          27  ...                          10
#
# [5 rows x 11 columns]

# %%
ytest.head()
# Out:
# 4657     0
# 56440    0
# 42117    1
# 10849    0
# 39395    0
# Name: loan_status, dtype: int64

# %%
xtrain.shape
# Out:
# (46916, 11)

# %%
xtest.shape
# Out:
# (11729, 11)

# %% [markdown]
# # Step 5 - Apply preprocessing

# %%
cat_cols = xtrain.select_dtypes(include="object").columns.tolist()
print(cat_cols)
# Out:
# ['person_home_ownership', 'loan_intent', 'loan_grade', 'cb_person_default_on_file']

# %%
num_cols = xtrain.select_dtypes(include="number").columns.tolist()
print(num_cols)
# Out:
# ['person_age', 'person_income', 'person_emp_length', 'loan_amnt', 'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length']

# %%
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
num_pipe = make_pipeline(
    SimpleImputer(strategy="median"),
    StandardScaler()
)

# %%
cat_pipe = make_pipeline(
    SimpleImputer(strategy="most_frequent"),
    OneHotEncoder(handle_unknown="ignore", sparse_output=False, drop="first")
)

# %%
pre = ColumnTransformer(
    [
        ("num", num_pipe, num_cols),
        ("cat", cat_pipe, cat_cols)
    ]
).set_output(transform="pandas")

pre.fit(xtrain)
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['person_age', 'person_income',
#                                   'person_emp_length', 'loan_amnt',
#                                   'loan_int_rate', 'loan_percent_income',
#                                   'cb_person_cred_hist_length']),
#                                 ('cat',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  ['person_home_ownership', 'loan_intent',
#                                   'loan_grade', 'cb_person_default_on_file'])])

# %%
xtrain_pre = pre.transform(xtrain)
xtrain_pre.head()
# Out:
#        num__person_age  ...  cat__cb_person_default_on_file_Y
# 14337         1.397825  ...                               1.0
# 17117        -0.091851  ...                               1.0
# 32590        -0.422891  ...                               0.0
# 55811         1.894383  ...                               0.0
# 40120        -0.919449  ...                               0.0
#
# [5 rows x 22 columns]

# %%
xtest_pre = pre.transform(xtest)
xtest_pre.head()
# Out:
#        num__person_age  ...  cat__cb_person_default_on_file_Y
# 4657         -0.753930  ...                               0.0
# 56440        -0.422891  ...                               0.0
# 42117         0.735746  ...                               0.0
# 10849        -0.919449  ...                               0.0
# 39395        -0.091851  ...                               0.0
#
# [5 rows x 22 columns]

# %%
xtrain_pre.shape
# Out:
# (46916, 22)

# %% [markdown]
# # Step 6 - Model building and algo evalution
# SVM and KNN is skipped because it is suitable for smaller datatsets upto 1000 rows

# %%
# !uv add xgboost
# Out:
# Resolved 123 packages in 121ms
# Audited 118 packages in 2ms

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, HistGradientBoostingClassifier
from xgboost import XGBClassifier

# %%
models = [
    LogisticRegression(),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    HistGradientBoostingClassifier(),
    XGBClassifier()
]

# %%
best_model, res = algo_evaluation(models, xtrain_pre, ytrain, xtest_pre, ytest)
# Out:
# {'model_name': 'LogisticRegression', 'model': LogisticRegression(), 'cv_mean': np.float64(0.7929), 'cv_std': np.float64(0.0071), 'f1_train': 0.793, 'f1_test': 0.7867, 'gen_err': 0.0063}
# {'model_name': 'DecisionTreeClassifier', 'model': DecisionTreeClassifier(), 'cv_mean': np.float64(0.8253), 'cv_std': np.float64(0.0038), 'f1_train': 1.0, 'f1_test': 0.8183, 'gen_err': 0.1817}
# {'model_name': 'RandomForestClassifier', 'model': RandomForestClassifier(), 'cv_mean': np.float64(0.8854), 'cv_std': np.float64(0.0053), 'f1_train': 0.9999, 'f1_test': 0.8904, 'gen_err': 0.1095}
# {'model_name': 'HistGradientBoostingClassifier', 'model': HistGradientBoostingClassifier(), 'cv_mean': np.float64(0.8903), 'cv_std': np.float64(0.0048), 'f1_train': 0.8985, 'f1_test': 0.892, 'gen_err': 0.0065}
# {'model_name': 'XGBClassifier', 'model': XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...), 'cv_mean': np.float64(0.8901), 'cv_std': np.float64(0.0057), 'f1_train': 0.9229, 'f1_test': 0.8939, 'gen_err': 0.029}

# %%
res
# Out:
#                        model_name  ... gen_err
# 0  HistGradientBoostingClassifier  ...  0.0065
# 1                   XGBClassifier  ...  0.0290
# 2          RandomForestClassifier  ...  0.1095
# 3          DecisionTreeClassifier  ...  0.1817
# 4              LogisticRegression  ...  0.0063
#
# [5 rows x 7 columns]

# %%
best_model
# Out:
# HistGradientBoostingClassifier()

# %% [markdown]
# # Above model has good f1 macro in train and test and cv and generalization error is also low

# %% [markdown]
# # Step 7 - Evaluate Selected model in detail

# %%
best_model
# Out:
# HistGradientBoostingClassifier()

# %%
best_model.score(xtrain_pre, ytrain)
# Out:
# 0.9551112626822406

# %%
best_model.score(xtest_pre, ytest)
# Out:
# 0.9525961292522807

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_estimator(best_model, xtest_pre, ytest)

# %%
ypred_test = best_model.predict(xtest_pre)
ypred_test[0:5]
# Out:
# array([0, 0, 0, 0, 0])

# %%
ytest.head()
# Out:
# 4657     0
# 56440    0
# 42117    1
# 10849    0
# 39395    0
# Name: loan_status, dtype: int64

# %%
from sklearn.metrics import classification_report

print(classification_report(ytest, ypred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     10087
#            1       0.92      0.73      0.81      1642
#
#     accuracy                           0.95     11729
#    macro avg       0.94      0.86      0.89     11729
# weighted avg       0.95      0.95      0.95     11729

# %%
from sklearn.metrics import RocCurveDisplay

RocCurveDisplay.from_estimator(best_model, xtest_pre, ytest)

# %% [markdown]
# # From above results the model can be used for out of sample data

# %% [markdown]
# # Step 8 - Out of Sample prediction

# %%
xnew = pd.read_csv("test_loan.csv")
xnew.head()
# Out:
#       id  person_age  ...  cb_person_default_on_file cb_person_cred_hist_length
# 0  58645          23  ...                          N                          2
# 1  58646          26  ...                          Y                          4
# 2  58647          26  ...                          Y                          2
# 3  58648          33  ...                          N                          7
# 4  58649          26  ...                          Y                          4
#
# [5 rows x 12 columns]

# %%
pre
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['person_age', 'person_income',
#                                   'person_emp_length', 'loan_amnt',
#                                   'loan_int_rate', 'loan_percent_income',
#                                   'cb_person_cred_hist_length']),
#                                 ('cat',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  ['person_home_ownership', 'loan_intent',
#                                   'loan_grade', 'cb_person_default_on_file'])])

# %%
xnew_pre = pre.transform(xnew)
xnew_pre.head()
# Out:
#    num__person_age  ...  cat__cb_person_default_on_file_Y
# 0        -0.753930  ...                               0.0
# 1        -0.257371  ...                               1.0
# 2        -0.257371  ...                               1.0
# 3         0.901266  ...                               0.0
# 4        -0.257371  ...                               1.0
#
# [5 rows x 22 columns]

# %%
preds = best_model.predict(xnew_pre)
preds[0:5]
# Out:
# array([1, 0, 1, 0, 0])

# %%
best_model.classes_
# Out:
# array([0, 1])

# %%
probs = best_model.predict_proba(xnew_pre)[:, 1]
probs[0:5]
# Out:
# array([0.99479263, 0.02717145, 0.6287762 , 0.01543655, 0.06584312])

# %%
final_res = xnew[["id"]]
final_res["loan_status"]= preds
final_res["probability"] = probs.round(4)

# %%
final_res
# Out:
#           id  loan_status  probability
# 0      58645            1       0.9948
# 1      58646            0       0.0272
# 2      58647            1       0.6288
# 3      58648            0       0.0154
# 4      58649            0       0.0658
# ...      ...          ...          ...
# 39093  97738            0       0.0566
# 39094  97739            0       0.0073
# 39095  97740            0       0.0180
# 39096  97741            0       0.3044
# 39097  97742            1       0.9476
#
# [39098 rows x 3 columns]

# %%
final_res["loan_status"].value_counts()
# Out:
# loan_status
# 0    34947
# 1     4151
# Name: count, dtype: int64

# %%
final_res["loan_status"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='loan_status'>

# %%
final_res.to_csv("loan_results.csv", index=False)

# %% [markdown]
# # Step 9 - Save the pre and model

# %%
pre
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['person_age', 'person_income',
#                                   'person_emp_length', 'loan_amnt',
#                                   'loan_int_rate', 'loan_percent_income',
#                                   'cb_person_cred_hist_length']),
#                                 ('cat',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  ['person_home_ownership', 'loan_intent',
#                                   'loan_grade', 'cb_person_default_on_file'])])

# %%
best_model
# Out:
# HistGradientBoostingClassifier()

# %%
import joblib

joblib.dump(pre, "pre.joblib")
# Out:
# ['pre.joblib']

# %%
joblib.dump(best_model, "loan_model.joblib")
# Out:
# ['loan_model.joblib']

# %% [markdown]
# # Load pre and models

# %%
p = joblib.load("pre.joblib")
p
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['person_age', 'person_income',
#                                   'person_emp_length', 'loan_amnt',
#                                   'loan_int_rate', 'loan_percent_income',
#                                   'cb_person_cred_hist_length']),
#                                 ('cat',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  ['person_home_ownership', 'loan_intent',
#                                   'loan_grade', 'cb_person_default_on_file'])])

# %%
m = joblib.load("loan_model.joblib")
m
# Out:
# HistGradientBoostingClassifier()

# %%
m.score(xtrain_pre, ytrain)
# Out:
# 0.9551112626822406

# %%
m.score(xtest_pre, ytest)
# Out:
# 0.9525961292522807
